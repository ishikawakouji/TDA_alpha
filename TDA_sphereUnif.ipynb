# %% [markdown]
# # sphereUnif
# This function samples n points from the sphere $S^d$ of radius r embedded in $R^{d+1}$, uniformly with
# respect to the volume measure of the sphere.

# %%
library(TDA)

X <- sphereUnif(n = 100, d = 1, r = 1)
plot(X)
# Out:
# plot without title
